# %%
num_sample = 300
num_burn = 100
sample_size = 800

# %%
from dgp import *

# 1. Simulate or load data
min_degree = 2
max_degree = 4
adj = get_graph(sample_size, min_degree, max_degree, seed=1)

tau = np.array([-1.0, 0.50, -0.50])       # shape (3,)
rho = np.array([[0,0.1,0.2],
                [0.1,0,0.1],
                [0.2,0.1,0]])      # shape (3, 3), with 0s on the diagonal
nu = np.array([0.1,0,0,0.1,0,0,0.1,0,0]).reshape(3,3)       # shape (3, 3)
gamma = np.array([-2.00,0.50,0.10,0.20,0.05,0.25,-0.08,0.30])     # shape (8,)
beta = np.array([-0.30,-0.60,-0.20,-0.20,-0.05,-0.10,-0.01,0.40,0.01,0.20])     # shape (10,)

Y_chain, A_chain, L_chain = sample_network_chain2(adj, tau, rho, nu, gamma, beta, R=num_sample,
    burnin_R=num_burn, seed=0)

Y_chain = Y_chain[::3]
A_chain = A_chain[::3]
L_chain = L_chain[::3]
# Out:
# 100%|██████████| 400/400 [00:13<00:00, 29.08it/s]

# %%
n_cpu = 10

# %%
from agcEffect import *

res_truth1 = agc_effect2(
    adj,
    tau, rho, nu, beta,
    treatment_allocation=0.7,
    R=200,
    burnin_R=50,
    seed=0
)
res_truth2 = agc_effect2(
    adj,
    tau, rho, nu, beta,
    treatment_allocation=0.3,
    R=200,
    burnin_R=50,
    seed=0
)

ground_truth1 = {'average': 0, 'direct': 0, 'indirect': 0, 'spillover_effect':0}
ground_truth1['average'] = res_truth1['average']
ground_truth1['direct'] = res_truth1['direct_effect']
ground_truth1['indirect'] = res_truth1['psi_0_gamma'] - res_truth2['psi_0_gamma']
ground_truth1['spillover_effect'] = res_truth1['spillover_effect']

ground_truth1
# Out:
# {'average': 0.28088125,
#  'direct': -0.14169374999999992,
#  'indirect': -0.06577500000000003,
#  'spillover_effect': -0.11949375000000007}

# %%
from utils import run_pll
from run_pll import run_dr_raw

treat_p = 0.7
args = [{'Y_chain': Y_chain,
         'A_chain': A_chain,
         'L_chain': L_chain,
         'adj': adj,
         'i': i,
         'treatment_allocation': treat_p,
         'psi_0_gamma_only': False} for i in range(len(Y_chain))]

res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
res_list_array_dr = np.array(res_list_dr)
# save results
np.save(f'run/sim_results/sim_dr_raw_{sample_size}_{min_degree}_{max_degree}_{treat_p}.npy', res_list_array_dr)
# Out:
# Multiprocessing <function run_dr_raw at 0x15c924d30> in 100 tasks, with 10 processes...
# Multiprocessing finished.

# %%
from utils import run_pll
from run_pll import run_dr_raw

treat_p = 0.3
args = [{'Y_chain': Y_chain,
         'A_chain': A_chain,
         'L_chain': L_chain,
         'adj': adj,
         'i': i,
         'treatment_allocation': treat_p,
         'psi_0_gamma_only': True} for i in range(len(Y_chain))]

res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
res_list_array_dr = np.array(res_list_dr)
# save results
np.save(f'run/sim_results/sim_dr_raw_{sample_size}_{min_degree}_{max_degree}_{treat_p}.npy', res_list_array_dr)
# Out:
# Multiprocessing <function run_dr_raw at 0x15c924d30> in 100 tasks, with 10 processes...
# Multiprocessing finished.

# %%
from dgp import *

# 1. Simulate or load data
min_degree = 5
max_degree = 7
adj = get_graph(sample_size, min_degree, max_degree, seed=1)

tau = np.array([-1.0, 0.50, -0.50])       # shape (3,)
rho = np.array([[0,0.1,0.2],
                [0.1,0,0.1],
                [0.2,0.1,0]])      # shape (3, 3), with 0s on the diagonal
nu = np.array([0.1,0,0,0.1,0,0,0.1,0,0]).reshape(3,3)       # shape (3, 3)
gamma = np.array([-2.00,0.50,0.10,0.20,0.05,0.25,-0.08,0.30])     # shape (8,)
beta = np.array([-0.30,-0.60,-0.20,-0.20,-0.05,-0.10,-0.01,0.40,0.01,0.20])     # shape (10,)

Y_chain, A_chain, L_chain = sample_network_chain2(adj, tau, rho, nu, gamma, beta, R=num_sample,
    burnin_R=num_burn, seed=0)

Y_chain = Y_chain[::3]
A_chain = A_chain[::3]
L_chain = L_chain[::3]
# Out:
# 100%|██████████| 400/400 [00:14<00:00, 27.81it/s]

# %%
from agcEffect import *

res_truth1 = agc_effect2(
    adj,
    tau, rho, nu, beta,
    treatment_allocation=0.7,
    R=200,
    burnin_R=50,
    seed=0
)
res_truth2 = agc_effect2(
    adj,
    tau, rho, nu, beta,
    treatment_allocation=0.3,
    R=200,
    burnin_R=50,
    seed=0
)

ground_truth2 = {'average': 0, 'direct': 0, 'indirect': 0, 'spillover_effect':0}
ground_truth2['average'] = res_truth1['average']
ground_truth2['direct'] = res_truth1['direct_effect']
ground_truth2['indirect'] = res_truth1['psi_0_gamma'] - res_truth2['psi_0_gamma']
ground_truth2['spillover_effect'] = res_truth1['spillover_effect']

ground_truth2
# Out:
# {'average': 0.213325,
#  'direct': -0.13479999999999998,
#  'indirect': -0.148075,
#  'spillover_effect': -0.26945625000000006}

# %%
from utils import run_pll
from run_pll import run_dr_raw

treat_p = 0.7
args = [{'Y_chain': Y_chain,
         'A_chain': A_chain,
         'L_chain': L_chain,
         'adj': adj,
         'i': i,
         'treatment_allocation': treat_p,
         'psi_0_gamma_only': False} for i in range(len(Y_chain))]

res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
res_list_array_dr = np.array(res_list_dr)
# save results
np.save(f'run/sim_results/sim_dr_raw_{sample_size}_{min_degree}_{max_degree}_{treat_p}.npy', res_list_array_dr)
# Out:
# Multiprocessing <function run_dr_raw at 0x14f466290> in 100 tasks, with 10 processes...
# Multiprocessing finished.

# %%
from utils import run_pll
from run_pll import run_dr_raw

treat_p = 0.3
args = [{'Y_chain': Y_chain,
         'A_chain': A_chain,
         'L_chain': L_chain,
         'adj': adj,
         'i': i,
         'treatment_allocation': treat_p,
         'psi_0_gamma_only': True} for i in range(len(Y_chain))]

res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
res_list_array_dr = np.array(res_list_dr)
# save results
np.save(f'run/sim_results/sim_dr_raw_{sample_size}_{min_degree}_{max_degree}_{treat_p}.npy', res_list_array_dr)
# Out:
# Multiprocessing <function run_dr_raw at 0x14f466290> in 100 tasks, with 10 processes...
# Process SpawnPoolWorker-16:
# Process SpawnPoolWorker-13:
# Process SpawnPoolWorker-11:
# Process SpawnPoolWorker-12:
# Process SpawnPoolWorker-20:
# Process SpawnPoolWorker-19:
# Process SpawnPoolWorker-14:
# Process SpawnPoolWorker-15:
# Process SpawnPoolWorker-18:
# Process SpawnPoolWorker-17:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 189, in doubly_robust
#     numerator, I = get_numerator_pi_vec(a_mat, A, GL, neighbours, gamma, adj_matrix, Atype='ind_treat_0')
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 102, in get_numerator_pi_vec
#     aa_out[i] = (mat_n_out * adj_max_n_out[:, :, None]).sum(axis=(0, 1))
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/_methods.py", line 46, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 189, in doubly_robust
#     numerator, I = get_numerator_pi_vec(a_mat, A, GL, neighbours, gamma, adj_matrix, Atype='ind_treat_0')
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 102, in get_numerator_pi_vec
#     aa_out[i] = (mat_n_out * adj_max_n_out[:, :, None]).sum(axis=(0, 1))
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/_methods.py", line 46, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 189, in doubly_robust
#     numerator, I = get_numerator_pi_vec(a_mat, A, GL, neighbours, gamma, adj_matrix, Atype='ind_treat_0')
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 102, in get_numerator_pi_vec
#     aa_out[i] = (mat_n_out * adj_max_n_out[:, :, None]).sum(axis=(0, 1))
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/_methods.py", line 46, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 189, in doubly_robust
#     numerator, I = get_numerator_pi_vec(a_mat, A, GL, neighbours, gamma, adj_matrix, Atype='ind_treat_0')
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 100, in get_numerator_pi_vec
#     mat_n_out = np.einsum('ik,j->ijk', vec_n, vec_n_out)
#   File "<__array_function__ internals>", line 180, in einsum
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/einsumfunc.py", line 1371, in einsum
#     return c_einsum(*operands, **kwargs)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 189, in doubly_robust
#     numerator, I = get_numerator_pi_vec(a_mat, A, GL, neighbours, gamma, adj_matrix, Atype='ind_treat_0')
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 100, in get_numerator_pi_vec
#     mat_n_out = np.einsum('ik,j->ijk', vec_n, vec_n_out)
#   File "<__array_function__ internals>", line 180, in einsum
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/einsumfunc.py", line 1371, in einsum
#     return c_einsum(*operands, **kwargs)
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 189, in doubly_robust
#     numerator, I = get_numerator_pi_vec(a_mat, A, GL, neighbours, gamma, adj_matrix, Atype='ind_treat_0')
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 102, in get_numerator_pi_vec
#     aa_out[i] = (mat_n_out * adj_max_n_out[:, :, None]).sum(axis=(0, 1))
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/_methods.py", line 46, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 189, in doubly_robust
#     numerator, I = get_numerator_pi_vec(a_mat, A, GL, neighbours, gamma, adj_matrix, Atype='ind_treat_0')
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 102, in get_numerator_pi_vec
#     aa_out[i] = (mat_n_out * adj_max_n_out[:, :, None]).sum(axis=(0, 1))
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/_methods.py", line 46, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 189, in doubly_robust
#     numerator, I = get_numerator_pi_vec(a_mat, A, GL, neighbours, gamma, adj_matrix, Atype='ind_treat_0')
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 100, in get_numerator_pi_vec
#     mat_n_out = np.einsum('ik,j->ijk', vec_n, vec_n_out)
#   File "<__array_function__ internals>", line 180, in einsum
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/einsumfunc.py", line 1371, in einsum
#     return c_einsum(*operands, **kwargs)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 189, in doubly_robust
#     numerator, I = get_numerator_pi_vec(a_mat, A, GL, neighbours, gamma, adj_matrix, Atype='ind_treat_0')
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 100, in get_numerator_pi_vec
#     mat_n_out = np.einsum('ik,j->ijk', vec_n, vec_n_out)
#   File "<__array_function__ internals>", line 180, in einsum
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/einsumfunc.py", line 1371, in einsum
#     return c_einsum(*operands, **kwargs)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 189, in doubly_robust
#     numerator, I = get_numerator_pi_vec(a_mat, A, GL, neighbours, gamma, adj_matrix, Atype='ind_treat_0')
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 102, in get_numerator_pi_vec
#     aa_out[i] = (mat_n_out * adj_max_n_out[:, :, None]).sum(axis=(0, 1))
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/_methods.py", line 46, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 13
#       4 treat_p = 0.3
#       5 args = [{'Y_chain': Y_chain,
#       6          'A_chain': A_chain,
#       7          'L_chain': L_chain,
#    (...)
#      10          'treatment_allocation': treat_p,
#      11          'psi_0_gamma_only': True} for i in range(len(Y_chain))]
# ---> 13 res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
#      14 res_list_array_dr = np.array(res_list_dr)
#      15 # save results
#
# File ~/Documents/DR/dr-chain-graph/utils.py:26, in run_pll(f, args, processes)
#      24     pool.apply_async(f, kwds=arg, callback=log_result, error_callback=log_error)
#      25 pool.close()
# ---> 26 pool.join()
#      28 if len(error_list):
#      29    print(f'{len(error_list)} jobs failed. ')
#
# File /opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py:665, in Pool.join(self)
#     663 elif self._state not in (CLOSE, TERMINATE):
#     664     raise ValueError("In unknown state")
# --> 665 self._worker_handler.join()
#     666 self._task_handler.join()
#     667 self._result_handler.join()
#
# File /opt/anaconda3/envs/ljz/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /opt/anaconda3/envs/ljz/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
from dgp import *

# 1. Simulate or load data
min_degree = 8
max_degree = 10
adj = get_graph(sample_size, min_degree, max_degree, seed=1)

tau = np.array([-1.0, 0.50, -0.50])       # shape (3,)
rho = np.array([[0,0.1,0.2],
                [0.1,0,0.1],
                [0.2,0.1,0]])      # shape (3, 3), with 0s on the diagonal
nu = np.array([0.1,0,0,0.1,0,0,0.1,0,0]).reshape(3,3)       # shape (3, 3)
gamma = np.array([-2.00,0.50,0.10,0.20,0.05,0.25,-0.08,0.30])     # shape (8,)
beta = np.array([-0.30,-0.60,-0.20,-0.20,-0.05,-0.10,-0.01,0.40,0.01,0.20])     # shape (10,)

Y_chain, A_chain, L_chain = sample_network_chain2(adj, tau, rho, nu, gamma, beta, R=num_sample,
    burnin_R=num_burn, seed=0)

Y_chain = Y_chain[::3]
A_chain = A_chain[::3]
L_chain = L_chain[::3]
# Out:
# 100%|██████████| 400/400 [00:14<00:00, 26.89it/s]

# %%
from agcEffect import *

res_truth1 = agc_effect2(
    adj,
    tau, rho, nu, beta,
    treatment_allocation=0.7,
    R=200,
    burnin_R=50,
    seed=0
)
res_truth2 = agc_effect2(
    adj,
    tau, rho, nu, beta,
    treatment_allocation=0.3,
    R=200,
    burnin_R=50,
    seed=0
)

ground_truth3 = {'average': 0, 'direct': 0, 'indirect': 0, 'spillover_effect':0}
ground_truth3['average'] = res_truth1['average']
ground_truth3['direct'] = res_truth1['direct_effect']
ground_truth3['indirect'] = res_truth1['psi_0_gamma'] - res_truth2['psi_0_gamma']
ground_truth3['spillover_effect'] = res_truth1['spillover_effect']

ground_truth3
# Out:
# {'average': 0.14641875000000001,
#  'direct': -0.10839374999999998,
#  'indirect': -0.24125624999999998,
#  'spillover_effect': -0.45620625000000004}

# %%
from utils import run_pll
from run_pll import run_dr_raw

treat_p = 0.7
args = [{'Y_chain': Y_chain,
         'A_chain': A_chain,
         'L_chain': L_chain,
         'adj': adj,
         'i': i,
         'treatment_allocation': treat_p,
         'psi_0_gamma_only': False} for i in range(len(Y_chain))]

res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
res_list_array_dr = np.array(res_list_dr)
# save results
np.save(f'run/sim_results/sim_dr_raw_{sample_size}_{min_degree}_{max_degree}_{treat_p}.npy', res_list_array_dr)
# Out:
# Multiprocessing <function run_dr_raw at 0x15c924d30> in 100 tasks, with 10 processes...
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:171: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# ...
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:208: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:196: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# /Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py:208: RuntimeWarning: invalid value encountered in divide
#   w_norm = w/np.sum(w)*N
# Process SpawnPoolWorker-48:
# Process SpawnPoolWorker-42:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 159, in doubly_robust
#     denominator = get_norm_constant(A, GL, neighbours, gamma, adj_matrix)
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 129, in get_norm_constant
#     aa_out[i] = (mat_n_out * adj_max_n_out[:, :, None]).sum(axis=(0, 1))
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/_methods.py", line 46, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt
# Process SpawnPoolWorker-44:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 159, in doubly_robust
#     denominator = get_norm_constant(A, GL, neighbours, gamma, adj_matrix)
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 129, in get_norm_constant
#     aa_out[i] = (mat_n_out * adj_max_n_out[:, :, None]).sum(axis=(0, 1))
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/_methods.py", line 48, in _sum
#     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# KeyboardInterrupt
# Process SpawnPoolWorker-45:
# Process SpawnPoolWorker-41:
# Process SpawnPoolWorker-50:
# Traceback (most recent call last):
# Process SpawnPoolWorker-49:
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 159, in doubly_robust
#     denominator = get_norm_constant(A, GL, neighbours, gamma, adj_matrix)
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 129, in get_norm_constant
#     aa_out[i] = (mat_n_out * adj_max_n_out[:, :, None]).sum(axis=(0, 1))
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/_methods.py", line 46, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 159, in doubly_robust
#     denominator = get_norm_constant(A, GL, neighbours, gamma, adj_matrix)
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 129, in get_norm_constant
#     aa_out[i] = (mat_n_out * adj_max_n_out[:, :, None]).sum(axis=(0, 1))
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/_methods.py", line 48, in _sum
#     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 159, in doubly_robust
#     denominator = get_norm_constant(A, GL, neighbours, gamma, adj_matrix)
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 129, in get_norm_constant
#     aa_out[i] = (mat_n_out * adj_max_n_out[:, :, None]).sum(axis=(0, 1))
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/_methods.py", line 46, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt
# Process SpawnPoolWorker-47:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 159, in doubly_robust
#     denominator = get_norm_constant(A, GL, neighbours, gamma, adj_matrix)
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 127, in get_norm_constant
#     mat_n_out = np.einsum('ik,j->ijk', vec_n, vec_n_out)
#   File "<__array_function__ internals>", line 180, in einsum
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/einsumfunc.py", line 1371, in einsum
#     return c_einsum(*operands, **kwargs)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 159, in doubly_robust
#     denominator = get_norm_constant(A, GL, neighbours, gamma, adj_matrix)
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 127, in get_norm_constant
#     mat_n_out = np.einsum('ik,j->ijk', vec_n, vec_n_out)
#   File "<__array_function__ internals>", line 180, in einsum
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/einsumfunc.py", line 1371, in einsum
#     return c_einsum(*operands, **kwargs)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 159, in doubly_robust
#     denominator = get_norm_constant(A, GL, neighbours, gamma, adj_matrix)
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 127, in get_norm_constant
#     mat_n_out = np.einsum('ik,j->ijk', vec_n, vec_n_out)
#   File "<__array_function__ internals>", line 180, in einsum
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/einsumfunc.py", line 1371, in einsum
#     return c_einsum(*operands, **kwargs)
# KeyboardInterrupt
# Process SpawnPoolWorker-46:
# Process SpawnPoolWorker-43:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 159, in doubly_robust
#     denominator = get_norm_constant(A, GL, neighbours, gamma, adj_matrix)
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 129, in get_norm_constant
#     aa_out[i] = (mat_n_out * adj_max_n_out[:, :, None]).sum(axis=(0, 1))
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/_methods.py", line 46, in _sum
#     def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 159, in doubly_robust
#     denominator = get_norm_constant(A, GL, neighbours, gamma, adj_matrix)
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 127, in get_norm_constant
#     mat_n_out = np.einsum('ik,j->ijk', vec_n, vec_n_out)
#   File "<__array_function__ internals>", line 180, in einsum
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/site-packages/numpy/core/einsumfunc.py", line 1371, in einsum
#     return c_einsum(*operands, **kwargs)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 13
#       4 treat_p = 0.7
#       5 args = [{'Y_chain': Y_chain,
#       6          'A_chain': A_chain,
#       7          'L_chain': L_chain,
#    (...)
#      10          'treatment_allocation': treat_p,
#      11          'psi_0_gamma_only': False} for i in range(len(Y_chain))]
# ---> 13 res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
#      14 res_list_array_dr = np.array(res_list_dr)
#      15 # save results
#
# File ~/Documents/DR/dr-chain-graph/utils.py:26, in run_pll(f, args, processes)
#      24     pool.apply_async(f, kwds=arg, callback=log_result, error_callback=log_error)
#      25 pool.close()
# ---> 26 pool.join()
#      28 if len(error_list):
#      29    print(f'{len(error_list)} jobs failed. ')
#
# File /opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py:665, in Pool.join(self)
#     663 elif self._state not in (CLOSE, TERMINATE):
#     664     raise ValueError("In unknown state")
# --> 665 self._worker_handler.join()
#     666 self._task_handler.join()
#     667 self._result_handler.join()
#
# File /opt/anaconda3/envs/ljz/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /opt/anaconda3/envs/ljz/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
from utils import run_pll
from run_pll import run_dr_raw

treat_p = 0.3
args = [{'Y_chain': Y_chain,
         'A_chain': A_chain,
         'L_chain': L_chain,
         'adj': adj,
         'i': i,
         'treatment_allocation': treat_p,
         'psi_0_gamma_only': True} for i in range(len(Y_chain))]

res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
res_list_array_dr = np.array(res_list_dr)
# save results
np.save(f'run/sim_results/sim_dr_raw_{sample_size}_{min_degree}_{max_degree}_{treat_p}.npy', res_list_array_dr)
# Out:
# Multiprocessing <function run_dr_raw at 0x312e24d30> in 100 tasks, with 10 processes...
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
#
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ljz/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/run_pll.py", line 50, in run_dr_raw
#     ret_i = doubly_robust(A_chain[i], L_chain[i], Y_chain[i], adj, treatment_allocation=treatment_allocation, seed=1, return_raw=True,
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/drnet.py", line 195, in doubly_robust
#     w = I[:,i] / pi_vec[:, i]
# UnboundLocalError: local variable 'pi_vec' referenced before assignment
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ljzljz/Documents/DR/dr-chain-graph/utils.py", line 17, in log_error
#     raise error
# UnboundLocalError: local variable 'pi_vec' referenced before assignment

# %% [markdown]
# ## Compute bias, std and etc

# %%
# read results
import numpy as np
from utils import compute_stats

results1 = np.load('run/sim_results/sim_dr_raw_800_2_4_0.7.npy', allow_pickle=True)
results2 = np.load('run/sim_results/sim_dr_raw_800_2_4_0.3.npy', allow_pickle=True)
results3 = np.load('run/sim_results/sim_dr_raw_800_5_7_0.7.npy', allow_pickle=True)
results4 = np.load('run/sim_results/sim_dr_raw_800_5_7_0.3.npy', allow_pickle=True)
results5 = np.load('run/sim_results/sim_dr_raw_800_8_10_0.7.npy', allow_pickle=True)
results6 = np.load('run/sim_results/sim_dr_raw_800_8_10_0.3.npy', allow_pickle=True)

print(compute_stats(results1, results2, ground_truth1))
print(compute_stats(results3, results4, ground_truth2))
print(compute_stats(results5, results6, ground_truth3))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 100%|██████████| 100/100 [00:00<00:00, 2454.83it/s]
# {'coverage_rate': array([0.92, 0.94, 0.98, 0.96]), 'bias': array([0.00987658, 0.02070243, 0.01094093, 0.0337907 ]), 'mse': array([0.00065375, 0.00346672, 0.00359786, 0.00873057]), 'var': array([0.0005562 , 0.00303813, 0.00347816, 0.00758876]), 'ci_length': array([0.08639123, 0.22894637, 0.23790619, 0.35120258]), 'true_effect': array([ 0.28088125, -0.14169375, -0.065775  , -0.11949375])}
# 100%|██████████| 100/100 [00:00<00:00, 2857.72it/s]
# {'coverage_rate': array([0.96, 0.9 , 0.97, 0.73]), 'bias': array([-0.00166743,  0.02974838,  0.03473117,  0.05498679]), 'mse': array([3.28386897e-04, 3.42813403e-03, 3.63608950e-02, 6.06005509e-01]), 'var': array([3.25606577e-04, 2.54316800e-03, 3.51546411e-02, 6.02981963e-01]), 'ci_length': array([0.0758199 , 0.2194742 , 0.65865971, 1.46928194]), 'true_effect': array([ 0.213325  , -0.1348    , -0.148075  , -0.26945625])}
# 100%|██████████| 100/100 [00:00<00:00, 2856.65it/s]
# {'coverage_rate': array([0.76, 0.85, 0.74, 0.47]), 'bias': array([-1.01183760e-02,  1.91684648e-02, -3.57461975e+01,  2.42029920e-01]), 'mse': array([1.16430833e-02, 1.40992040e+00, 1.29589081e+05, 1.39341554e+00]), 'var': array([1.15407018e-02, 1.40955297e+00, 1.28311290e+05, 1.33483706e+00]), 'ci_length': array([  0.22253894,   1.4170529 , 142.58524194,   1.3055892 ]), 'true_effect': array([ 0.14641875, -0.10839375, -0.24125625, -0.45620625])}

# %%
# ['psi_gamma', 'psi_zero', 'psi_1_gamma', 'psi_0_gamma']
print(
results1.mean(axis=(0,1))[0],
results1.mean(axis=(0,1))[2] - results1.mean(axis=(0,1))[3],
results1.mean(axis=(0,1))[3] - results1.mean(axis=(0,1))[1])
# Out:
# 0.29075782988535875 -0.12099132124082657 -0.08570305251891014

# %%
print(
results3.mean(axis=(0,1))[0],
results3.mean(axis=(0,1))[2] - results3.mean(axis=(0,1))[3],
results3.mean(axis=(0,1))[3] - results3.mean(axis=(0,1))[1])
# Out:
# 0.21165757075264446 -0.10505162137488838 -0.21446946407851308

# %%
print(
results5.mean(axis=(0,1))[0],
results5.mean(axis=(0,1))[2] - results5.mean(axis=(0,1))[3],
results5.mean(axis=(0,1))[3] - results5.mean(axis=(0,1))[1])
# Out:
# 0.1363003740030573 -0.08922528515259733 -0.21417633006670883
