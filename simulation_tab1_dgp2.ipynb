# %%
num_sample = 3000
num_burn = 1000
sample_size = 800

# %%
from dgp import *

# 1. Simulate or load data
min_degree = 2
max_degree = 4
adj = get_graph(sample_size, min_degree, max_degree, seed=1)

tau = np.array([-1.0, 0.50, -0.50])       # shape (3,)
rho = np.array([[0,0.1,0.2],
                [0.1,0,0.1],
                [0.2,0.1,0]])      # shape (3, 3), with 0s on the diagonal
nu = np.array([0.1,0,0,0.1,0,0,0.1,0,0]).reshape(3,3)       # shape (3, 3)
gamma = np.array([-2.00,0.50,-0.05,0.20,0.05,0.25,-0.08,0.30])     # shape (8,)
beta = np.array([-0.30,-0.60,-0.20,-0.20,-0.05,-0.10,-0.01,0.40,0.01,0.20])     # shape (10,)

Y_chain, A_chain, L_chain = sample_network_chain2(adj, tau, rho, nu, gamma, beta, R=num_sample,
    burnin_R=num_burn, seed=0)

Y_chain = Y_chain[::3]
A_chain = A_chain[::3]
L_chain = L_chain[::3]

# %%
n_cpu = 100

# %%
from agcEffect import *

res_truth1 = agc_effect2(
    adj,
    tau, rho, nu, beta,
    treatment_allocation=0.7,
    R=200,
    burnin_R=50,
    seed=0
)
res_truth2 = agc_effect2(
    adj,
    tau, rho, nu, beta,
    treatment_allocation=0.3,
    R=200,
    burnin_R=50,
    seed=0
)

ground_truth1 = {'average': 0, 'direct': 0, 'indirect': 0, 'spillover_effect':0}
ground_truth1['average'] = res_truth1['average']
ground_truth1['direct'] = res_truth1['direct_effect']
ground_truth1['indirect'] = res_truth1['psi_0_gamma'] - res_truth2['psi_0_gamma']
ground_truth1['spillover_effect'] = res_truth1['spillover_effect']

ground_truth1

# %%
from utils import run_pll
from run_pll import run_dr_raw

treat_p = 0.7
args = [{'Y_chain': Y_chain,
         'A_chain': A_chain,
         'L_chain': L_chain,
         'adj': adj,
         'i': i,
         'treatment_allocation': treat_p,
         'psi_0_gamma_only': False} for i in range(len(Y_chain))]

res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
res_list_array_dr = np.array(res_list_dr)
# save results
np.save(f'run/sim_results/sim_dr_raw_dgp2_{sample_size}_{min_degree}_{max_degree}_{treat_p}.npy', res_list_array_dr)

# %%
from utils import run_pll
from run_pll import run_dr_raw

treat_p = 0.3
args = [{'Y_chain': Y_chain,
         'A_chain': A_chain,
         'L_chain': L_chain,
         'adj': adj,
         'i': i,
         'treatment_allocation': treat_p,
         'psi_0_gamma_only': True} for i in range(len(Y_chain))]

res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
res_list_array_dr = np.array(res_list_dr)
# save results
np.save(f'run/sim_results/sim_dr_raw_dgp2_{sample_size}_{min_degree}_{max_degree}_{treat_p}.npy', res_list_array_dr)

# %%
from dgp import *

# 1. Simulate or load data
min_degree = 5
max_degree = 7
adj = get_graph(sample_size, min_degree, max_degree, seed=1)

tau = np.array([-1.0, 0.50, -0.50])       # shape (3,)
rho = np.array([[0,0.1,0.2],
                [0.1,0,0.1],
                [0.2,0.1,0]])      # shape (3, 3), with 0s on the diagonal
nu = np.array([0.1,0,0,0.1,0,0,0.1,0,0]).reshape(3,3)       # shape (3, 3)
gamma = np.array([-2.00,0.50,-0.05,0.20,0.05,0.25,-0.08,0.30])     # shape (8,)
beta = np.array([-0.30,-0.60,-0.20,-0.20,-0.05,-0.10,-0.01,0.40,0.01,0.20])     # shape (10,)

Y_chain, A_chain, L_chain = sample_network_chain2(adj, tau, rho, nu, gamma, beta, R=num_sample,
    burnin_R=num_burn, seed=0)

Y_chain = Y_chain[::3]
A_chain = A_chain[::3]
L_chain = L_chain[::3]

# %%
from agcEffect import *

res_truth1 = agc_effect2(
    adj,
    tau, rho, nu, beta,
    treatment_allocation=0.7,
    R=200,
    burnin_R=50,
    seed=0
)
res_truth2 = agc_effect2(
    adj,
    tau, rho, nu, beta,
    treatment_allocation=0.3,
    R=200,
    burnin_R=50,
    seed=0
)

ground_truth2 = {'average': 0, 'direct': 0, 'indirect': 0, 'spillover_effect':0}
ground_truth2['average'] = res_truth1['average']
ground_truth2['direct'] = res_truth1['direct_effect']
ground_truth2['indirect'] = res_truth1['psi_0_gamma'] - res_truth2['psi_0_gamma']
ground_truth2['spillover_effect'] = res_truth1['spillover_effect']

ground_truth2

# %%
from utils import run_pll
from run_pll import run_dr_raw

treat_p = 0.7
args = [{'Y_chain': Y_chain,
         'A_chain': A_chain,
         'L_chain': L_chain,
         'adj': adj,
         'i': i,
         'treatment_allocation': treat_p,
         'psi_0_gamma_only': False} for i in range(len(Y_chain))]

res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
res_list_array_dr = np.array(res_list_dr)
# save results
np.save(f'run/sim_results/sim_dr_raw_dgp2_{sample_size}_{min_degree}_{max_degree}_{treat_p}.npy', res_list_array_dr)

# %%
from utils import run_pll
from run_pll import run_dr_raw

treat_p = 0.3
args = [{'Y_chain': Y_chain,
         'A_chain': A_chain,
         'L_chain': L_chain,
         'adj': adj,
         'i': i,
         'treatment_allocation': treat_p,
         'psi_0_gamma_only': True} for i in range(len(Y_chain))]

res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
res_list_array_dr = np.array(res_list_dr)
# save results
np.save(f'run/sim_results/sim_dr_raw_dgp2_{sample_size}_{min_degree}_{max_degree}_{treat_p}.npy', res_list_array_dr)

# %%
from dgp import *

# 1. Simulate or load data
min_degree = 8
max_degree = 10
adj = get_graph(sample_size, min_degree, max_degree, seed=1)

tau = np.array([-1.0, 0.50, -0.50])       # shape (3,)
rho = np.array([[0,0.1,0.2],
                [0.1,0,0.1],
                [0.2,0.1,0]])      # shape (3, 3), with 0s on the diagonal
nu = np.array([0.1,0,0,0.1,0,0,0.1,0,0]).reshape(3,3)       # shape (3, 3)
gamma = np.array([-2.00,0.50,-0.05,0.20,0.05,0.25,-0.08,0.30])     # shape (8,)
beta = np.array([-0.30,-0.60,-0.20,-0.20,-0.05,-0.10,-0.01,0.40,0.01,0.20])     # shape (10,)

Y_chain, A_chain, L_chain = sample_network_chain2(adj, tau, rho, nu, gamma, beta, R=num_sample,
    burnin_R=num_burn, seed=0)

Y_chain = Y_chain[::3]
A_chain = A_chain[::3]
L_chain = L_chain[::3]

# %%
from agcEffect import *

res_truth1 = agc_effect2(
    adj,
    tau, rho, nu, beta,
    treatment_allocation=0.7,
    R=200,
    burnin_R=50,
    seed=0
)
res_truth2 = agc_effect2(
    adj,
    tau, rho, nu, beta,
    treatment_allocation=0.3,
    R=200,
    burnin_R=50,
    seed=0
)

ground_truth3 = {'average': 0, 'direct': 0, 'indirect': 0, 'spillover_effect':0}
ground_truth3['average'] = res_truth1['average']
ground_truth3['direct'] = res_truth1['direct_effect']
ground_truth3['indirect'] = res_truth1['psi_0_gamma'] - res_truth2['psi_0_gamma']
ground_truth3['spillover_effect'] = res_truth1['spillover_effect']

ground_truth3

# %%
from utils import run_pll
from run_pll import run_dr_raw

treat_p = 0.7
args = [{'Y_chain': Y_chain,
         'A_chain': A_chain,
         'L_chain': L_chain,
         'adj': adj,
         'i': i,
         'treatment_allocation': treat_p,
         'psi_0_gamma_only': False} for i in range(len(Y_chain))]

res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
res_list_array_dr = np.array(res_list_dr)
# save results
np.save(f'run/sim_results/sim_dr_raw_dgp2_{sample_size}_{min_degree}_{max_degree}_{treat_p}.npy', res_list_array_dr)

# %%
from utils import run_pll
from run_pll import run_dr_raw

treat_p = 0.3
args = [{'Y_chain': Y_chain,
         'A_chain': A_chain,
         'L_chain': L_chain,
         'adj': adj,
         'i': i,
         'treatment_allocation': treat_p,
         'psi_0_gamma_only': True} for i in range(len(Y_chain))]

res_list_dr = run_pll(run_dr_raw, args, processes=n_cpu)
res_list_array_dr = np.array(res_list_dr)
# save results
np.save(f'run/sim_results/sim_dr_raw_dgp2_{sample_size}_{min_degree}_{max_degree}_{treat_p}.npy', res_list_array_dr)

# %% [markdown]
# ## Compute bias, std and etc

# %%
# read results
import numpy as np
from utils import compute_stats

results1 = np.load('run/sim_results/sim_dr_raw_dgp2_800_2_4_0.7.npy', allow_pickle=True)
results2 = np.load('run/sim_results/sim_dr_raw_dgp2_800_2_4_0.3.npy', allow_pickle=True)
results3 = np.load('run/sim_results/sim_dr_raw_dgp2_800_5_7_0.7.npy', allow_pickle=True)
results4 = np.load('run/sim_results/sim_dr_raw_dgp2_800_5_7_0.3.npy', allow_pickle=True)
results5 = np.load('run/sim_results/sim_dr_raw_dgp2_800_8_10_0.7.npy', allow_pickle=True)
results6 = np.load('run/sim_results/sim_dr_raw_dgp2_800_8_10_0.3.npy', allow_pickle=True)

print(compute_stats(results1, results2, ground_truth1))
print(compute_stats(results3, results4, ground_truth2))
print(compute_stats(results5, results6, ground_truth3))

# %%
# ['psi_gamma', 'psi_zero', 'psi_1_gamma', 'psi_0_gamma']
print(
results1.mean(axis=(0,1))[0],
results1.mean(axis=(0,1))[2] - results1.mean(axis=(0,1))[3],
results1.mean(axis=(0,1))[3] - results1.mean(axis=(0,1))[1])

# %%
print(
results3.mean(axis=(0,1))[0],
results3.mean(axis=(0,1))[2] - results3.mean(axis=(0,1))[3],
results3.mean(axis=(0,1))[3] - results3.mean(axis=(0,1))[1])

# %%
print(
results5.mean(axis=(0,1))[0],
results5.mean(axis=(0,1))[2] - results5.mean(axis=(0,1))[3],
results5.mean(axis=(0,1))[3] - results5.mean(axis=(0,1))[1])
